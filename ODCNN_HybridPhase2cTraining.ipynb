# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Optical_MNIST
# Out:
# /content/drive/MyDrive/Optical_MNIST

# %%
# Standard Phase 2c training (200x200 grid)
# !python main_phase2_hybrid.py --shift-range 7

# FALLBACK (Run this instead if you encounter 'Out of Memory' on a T4):
# !python main_phase2_hybrid.py --iters 10000 --batch 32 --shift-range 5 --grid-size 128 --num-kernels 9 --kernel-size 7
# Out:
# Device: cuda
# ComplexModulationD2NN: 5 layers, 200×200
#   z_spacing = 5.00 cm
#   Diffraction spot ~= 12.2 px
# Total parameters: 401,296
#
# ODCNN Hybrid: 200×200, 16 kernels of 9×9
# D²NN: 5 layers, complex modulation
# Loss: MSE on softmax (Sensors 2023 eq. 5)
# Batch: 64, Iters: 10000, LR: 0.001
# Shift augmentation: ±7 px
#
# Amplitude encoding check: E_in.abs().std() (nonzero pixels) = 0.3453 (OK -- varying amplitude)
#   Gradient check: amp_logits[0].grad.norm=0.000002, phase_masks[0].grad.norm=0.000003
# iter    50  loss=0.0900  train_acc(last 50)=0.142
# iter   100  loss=0.0897  train_acc(last 50)=0.108
# iter   150  loss=0.0886  train_acc(last 50)=0.118
# iter   200  loss=0.0872  train_acc(last 50)=0.179
# iter   250  loss=0.0840  train_acc(last 50)=0.268
# iter   300  loss=0.0814  train_acc(last 50)=0.317
# iter   350  loss=0.0762  train_acc(last 50)=0.423
# iter   400  loss=0.0711  train_acc(last 50)=0.481
# iter   450  loss=0.0675  train_acc(last 50)=0.514
# ...
